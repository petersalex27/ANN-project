# %%
import matplotlib.pyplot as plt
import numpy as np
from skimage.color import rgb2lab, lab2rgb
# %matplotlib inline
import cv2

"""
ssim(firstImage, secondImage)
- comp. the two images and returns a floating point num in the range [0, 1]
- 0 is no similarity, 1 is entirely similar
"""
from skimage.metrics import structural_similarity as ssim

# %%
bwPath = "/content/drive/MyDrive/Colab Notebooks/ANN-Project/gray_scale.npy"
abL1Path = "/content/drive/MyDrive/Colab Notebooks/ANN-Project/ab1.npy"
abL2Path = "/content/drive/MyDrive/Colab Notebooks/ANN-Project/ab2.npy"
abL3Path = "/content/drive/MyDrive/Colab Notebooks/ANN-Project/ab3.npy" 

bwData = np.load(bwPath)
abData = np.array([np.load(abL1Path), np.load(abL2Path), np.load(abL3Path)])
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:7: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   import sys

# %%
""" function: showim
displays b/w image given an index and a multi-dim. matrix of images

param i - index of image in matrix of image data
param data - matrix of image data (optional)
"""
def showim(i:int, data=bwData):
  #                   properly renders the image in b/w
  #                   (else it assumes it is a color image)
  #                   v---------------------------v
  plt.imshow(data[i], cmap='gray', vmin=0, vmax=255)

# %%
import skimage
ab1Data = abData[0]
ab2Data = abData[1]
ab3Data = abData[2]
data = np.ndarray((25000, 224, 224, 3))

# TODO, idk if this is correct: trying to load bw layer to [?][?][?][0]
# and a and b layers to [?][?][?][1 and 2]
data[:, :, :, :, 0] = bwData
data[:, :, :, 1:] = abData[0]
data[:, :, :, 10001:] = abData[1]
data[:, :, :, 20001:] = abData[2]

data = data.astype('uint8')
cv2.cvtColor(data, cv2.COLOR_LAB2BGR)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-a7d6107cd496> in <module>()
#       1 import skimage
# ----> 2 ab1Data = abData[0]
#       3 ab2Data = abData[1]
#       4 ab3Data = abData[2]
#       5 data = np.ndarray((25000, 224, 224, 3))
#
# NameError: name 'abData' is not defined
